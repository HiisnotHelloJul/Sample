# %% [markdown]
# <a href="https://colab.research.google.com/github/HiisnotHelloJul/Sample/blob/main/Q1_Narra_FA1_Santero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

x1 = int(input ("x1: "))
x2 = int(input ("x2: "))
y1 = int(input ("y1: "))
y2 = int(input ("y2: "))

distance = math.sqrt(math.pow(x2 - x1, 2) + math.pow(y2 - y1, 2))

print("The distance between the two points is:", round(distance, 2))
# Out:
# x1: 2
# x2: 7
# y1: 3
# y2: 8
# The distance between the two points is: 7.07
